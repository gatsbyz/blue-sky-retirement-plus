# %%
import folium
import pandas as pd

# %%
my_map3 = folium.Map(location=[39.828175, -98.5795],
    zoom_start=5
    )

# %%
#setting Markers for selected cities. 
#MAdera, CA

mk = folium.Marker([36.899097, -119.795166])
pp = folium.Popup('Madera, CA')
ic = folium.Icon(color='red')

mk.add_child(ic)
mk.add_child(pp)
my_map3.add_child(mk)

#Lake Havasu City-Kingman, AZ
mk2 = folium.Marker([34.483696, -114.325638 ])
pp2 = folium.Popup('Lake Havasu City-Kingman, AZ')
ic2 = folium.Icon(color='blue')

mk2.add_child(ic2)
mk2.add_child(pp2)
my_map3.add_child(mk2)

#Palm Bay-Melbourne-Titusville

mk3 = folium.Marker([28.040169, -80.594330])
pp3 = folium.Popup('Palm Bay-Melbourne-Titusville')
ic3 = folium.Icon(color='orange')

mk3.add_child(ic3)
mk3.add_child(pp3)
my_map3.add_child(mk3)

#The Villages, FL
mk4 = folium.Marker([28.927019, -82.003761])
pp4 = folium.Popup('The Villages, FL')
ic4 = folium.Icon(color='green')

mk4.add_child(ic4)
mk4.add_child(pp4)
my_map3.add_child(mk4)

#Lakeland-Winter Haven
mk5 = folium.Marker([28.022243, -81.732857])
pp5 = folium.Popup("Lakeland-Winter Haven")
ic5 = folium.Icon(color='pink')

mk5.add_child(ic5)
mk5.add_child(pp5)
my_map3.add_child(mk5)

#Idaho Falls, ID
mk6 = folium.Marker([43.491650, -112.033966])
pp6 = folium.Popup("Idaho Falls, ID")
ic6 = folium.Icon(color="black")

mk6.add_child(ic6)
mk6.add_child(pp6)
my_map3.add_child(mk6)

#Boise City, ID
mk7 = folium.Marker([43.618881, -116.215019])
pp7 = folium.Popup('Boise City, ID')
ic7 = folium.Icon(color='purple')

mk7.add_child(ic7)
mk7.add_child(pp7)
my_map3.add_child(mk7)

#St. George, UT
mk8 = folium.Marker([37.0951699, -113.575974])
pp8 = folium.Popup("St. George, UT")
ic8 = folium.Icon(color='cadetblue')

mk8.add_child(ic8)
mk8.add_child(pp8)
my_map3.add_child(mk8)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5553f69addd9fa3cb354be882e9dd74e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5553f69addd9fa3cb354be882e9dd74e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_5553f69addd9fa3cb354be882e9dd74e = L.map(
#                 &quot;map_5553f69addd9fa3cb354be882e9dd74e&quot;,
#                 {
#                     center: [39.828175, -98.5795],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6f643131d018401d184ee95e0e0bf50f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5553f69addd9fa3cb354be882e9dd74e);
#
#
#             var marker_f3dcd90a4e259829d9112845031d78f8 = L.marker(
#                 [36.899097, -119.795166],
#                 {}
#             ).addTo(map_5553f69addd9fa3cb354be882e9dd74e);
#
#
#             var icon_46ef14b36f72875911a02b4730ac72c2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f3dcd90a4e259829d9112845031d78f8.setIcon(icon_46ef14b36f72875911a02b4730ac72c2);
#
#
#         var popup_ed171148fd5525f8adfe3e17058a330d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_7accfe50e568521ead94595228850897 = $(`&lt;div id=&quot;html_7accfe50e568521ead94595228850897&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Madera, CA&lt;/div&gt;`)[0];
#             popup_ed171148fd5525f8adfe3e17058a330d.setContent(html_7accfe50e568521ead94595228850897);
#
#
#         marker_f3dcd90a4e259829d9112845031d78f8.bindPopup(popup_ed171148fd5525f8adfe3e17058a330d)
#         ;
#
#
#
#
#             var marker_bbb652c73da956c2197579fecb7e8ee1 = L.marker(
#                 [34.483696, -114.325638],
#                 {}
#             ).addTo(map_5553f69addd9fa3cb354be882e9dd74e);
#
#
#             var icon_9d479781753e828ae2350ec24a11a10a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_bbb652c73da956c2197579fecb7e8ee1.setIcon(icon_9d479781753e828ae2350ec24a11a10a);
#
#
#         var popup_5972dcb62ae4934483636f99e3b215b0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_c335692415a58d447e38f4540305c47c = $(`&lt;div id=&quot;html_c335692415a58d447e38f4540305c47c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lake Havasu City-Kingman, AZ&lt;/div&gt;`)[0];
#             popup_5972dcb62ae4934483636f99e3b215b0.setContent(html_c335692415a58d447e38f4540305c47c);
#
#
#         marker_bbb652c73da956c2197579fecb7e8ee1.bindPopup(popup_5972dcb62ae4934483636f99e3b215b0)
#         ;
#
#
#
#
#             var marker_5db5f78666141b24ff066ada005eb391 = L.marker(
#                 [28.040169, -80.59433],
#                 {}
#             ).addTo(map_5553f69addd9fa3cb354be882e9dd74e);
#
#
#             var icon_210ff727fcf99fe01ceb5873eca35ed2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5db5f78666141b24ff066ada005eb391.setIcon(icon_210ff727fcf99fe01ceb5873eca35ed2);
#
#
#         var popup_93c6ccc3bad07faed930beeba9b08d94 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_d349615efefe56eae85bcce9de62f120 = $(`&lt;div id=&quot;html_d349615efefe56eae85bcce9de62f120&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Palm Bay-Melbourne-Titusville&lt;/div&gt;`)[0];
#             popup_93c6ccc3bad07faed930beeba9b08d94.setContent(html_d349615efefe56eae85bcce9de62f120);
#
#
#         marker_5db5f78666141b24ff066ada005eb391.bindPopup(popup_93c6ccc3bad07faed930beeba9b08d94)
#         ;
#
#
#
#
#             var marker_72a2593b39cba51e00e5e072c78ee5b4 = L.marker(
#                 [28.927019, -82.003761],
#                 {}
#             ).addTo(map_5553f69addd9fa3cb354be882e9dd74e);
#
#
#             var icon_75e0382b3363f3eb39a55ba256b7e3e0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_72a2593b39cba51e00e5e072c78ee5

# %%
my_map3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5553f69addd9fa3cb354be882e9dd74e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5553f69addd9fa3cb354be882e9dd74e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_5553f69addd9fa3cb354be882e9dd74e = L.map(
#                 &quot;map_5553f69addd9fa3cb354be882e9dd74e&quot;,
#                 {
#                     center: [39.828175, -98.5795],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6f643131d018401d184ee95e0e0bf50f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5553f69addd9fa3cb354be882e9dd74e);
#
#
#             var marker_f3dcd90a4e259829d9112845031d78f8 = L.marker(
#                 [36.899097, -119.795166],
#                 {}
#             ).addTo(map_5553f69addd9fa3cb354be882e9dd74e);
#
#
#             var icon_46ef14b36f72875911a02b4730ac72c2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f3dcd90a4e259829d9112845031d78f8.setIcon(icon_46ef14b36f72875911a02b4730ac72c2);
#
#
#         var popup_ed171148fd5525f8adfe3e17058a330d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_7accfe50e568521ead94595228850897 = $(`&lt;div id=&quot;html_7accfe50e568521ead94595228850897&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Madera, CA&lt;/div&gt;`)[0];
#             popup_ed171148fd5525f8adfe3e17058a330d.setContent(html_7accfe50e568521ead94595228850897);
#
#
#         marker_f3dcd90a4e259829d9112845031d78f8.bindPopup(popup_ed171148fd5525f8adfe3e17058a330d)
#         ;
#
#
#
#
#             var marker_bbb652c73da956c2197579fecb7e8ee1 = L.marker(
#                 [34.483696, -114.325638],
#                 {}
#             ).addTo(map_5553f69addd9fa3cb354be882e9dd74e);
#
#
#             var icon_9d479781753e828ae2350ec24a11a10a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_bbb652c73da956c2197579fecb7e8ee1.setIcon(icon_9d479781753e828ae2350ec24a11a10a);
#
#
#         var popup_5972dcb62ae4934483636f99e3b215b0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_c335692415a58d447e38f4540305c47c = $(`&lt;div id=&quot;html_c335692415a58d447e38f4540305c47c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lake Havasu City-Kingman, AZ&lt;/div&gt;`)[0];
#             popup_5972dcb62ae4934483636f99e3b215b0.setContent(html_c335692415a58d447e38f4540305c47c);
#
#
#         marker_bbb652c73da956c2197579fecb7e8ee1.bindPopup(popup_5972dcb62ae4934483636f99e3b215b0)
#         ;
#
#
#
#
#             var marker_5db5f78666141b24ff066ada005eb391 = L.marker(
#                 [28.040169, -80.59433],
#                 {}
#             ).addTo(map_5553f69addd9fa3cb354be882e9dd74e);
#
#
#             var icon_210ff727fcf99fe01ceb5873eca35ed2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5db5f78666141b24ff066ada005eb391.setIcon(icon_210ff727fcf99fe01ceb5873eca35ed2);
#
#
#         var popup_93c6ccc3bad07faed930beeba9b08d94 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_d349615efefe56eae85bcce9de62f120 = $(`&lt;div id=&quot;html_d349615efefe56eae85bcce9de62f120&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Palm Bay-Melbourne-Titusville&lt;/div&gt;`)[0];
#             popup_93c6ccc3bad07faed930beeba9b08d94.setContent(html_d349615efefe56eae85bcce9de62f120);
#
#
#         marker_5db5f78666141b24ff066ada005eb391.bindPopup(popup_93c6ccc3bad07faed930beeba9b08d94)
#         ;
#
#
#
#
#             var marker_72a2593b39cba51e00e5e072c78ee5b4 = L.marker(
#                 [28.927019, -82.003761],
#                 {}
#             ).addTo(map_5553f69addd9fa3cb354be882e9dd74e);
#
#
#             var icon_75e0382b3363f3eb39a55ba256b7e3e0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_72a2593b39cba51e00e5e072c78ee5
