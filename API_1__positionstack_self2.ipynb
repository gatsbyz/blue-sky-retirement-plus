# %%
# Python 3
import http.client, urllib.parse

conn = http.client.HTTPConnection('api.positionstack.com')

Albany_Lebanon_OR = urllib.parse.urlencode({
    'access_key': '2f18961718a89cea8627fcc20480d31a',
    'query': 'Albany-Lebanon',
    'region': 'Oregon ',
    'limit': 1,
    })

Boise_City_ID = urllib.parse.urlencode({
    'access_key': '2f18961718a89cea8627fcc20480d31a',
    'query': 'Boise',
    'region': 'Idaho',
    'limit': 1,
    })

Austin_Round_Rock_georgetown_TX = urllib.parse.urlencode({
    'access_key': '2f18961718a89cea8627fcc20480d31a',
    'query': 'Austin-Round Rock-Georgetown',
    'region': 'Texas ',
    'limit': 1,
    })
Bellingham_WA = urllib.parse.urlencode({
    'access_key': '2f18961718a89cea8627fcc20480d31a',
    'query': 'Bellingham',
    'region': 'Washington ',
    'limit': 1,
    })
Bend_OR = urllib.parse.urlencode({
    'access_key': '2f18961718a89cea8627fcc20480d31a',
    'query': 'Bend',
    'region': 'Oregon ',
    'limit': 1,
    })
Bremerton_Silverdale_port_orchard__WA = urllib.parse.urlencode({
    'access_key': '2f18961718a89cea8627fcc20480d31a',
    'query': 'Bremerton-Silverdale-Port Orchard',
    'region': 'Washington ',
    'limit': 1,
    })
Carson_city_NV = urllib.parse.urlencode({
    'access_key': '2f18961718a89cea8627fcc20480d31a',
    'query': 'Bremerton-Silverdale-Port Orchard',
    'region': 'Washington ',
    'limit': 1,
    })
Coeur_d_alene_ID = urllib.parse.urlencode({
    'access_key': '2f18961718a89cea8627fcc20480d31a',
    'query': "'BCoeur d'Alene'",
    'region': 'Idaho',
    'limit': 1,
    })
Colorado_Springs_CO =  urllib.parse.urlencode({
    'access_key': '2f18961718a89cea8627fcc20480d31a',
    'query': 'Colorado Springs',
    'region': 'Colorado',
    'limit': 1,
    })
Deltona_Daytona_beach_ormond_beach_FL = urllib.parse.urlencode({
    'access_key': '2f18961718a89cea8627fcc20480d31a',
    'query': 'Deltona-Daytona Beach-Ormond Beach',
    'region': 'Florida ',
    'limit': 1,
    })
Homosassa_Springs_FL = urllib.parse.urlencode({
    'access_key': '2f18961718a89cea8627fcc20480d31a',
    'query': 'Homosassa Springs',
    'region': 'Florida ',
    'limit': 1,
    })
Idaho_dalls_ID = urllib.parse.urlencode({
    'access_key': '2f18961718a89cea8627fcc20480d31a',
    'query': 'Idaho_Falls',
    'region': 'Idaho ',
    'limit': 1,
    })
Kennewick_Richland_WA = urllib.parse.urlencode({
    'access_key': '2f18961718a89cea8627fcc20480d31a',
    'query': 'Kenwick in Richland',
    'region': 'Washington',
    'limit': 1,
    })
Lake_havasu_CITY_Kingman_AZ = urllib.parse.urlencode({
    'access_key': '2f18961718a89cea8627fcc20480d31a',
    'query': 'Lake Havasu City-Kingman',
    'region': 'Arizona',
    'limit': 1,
    })
Lake_Winterland_Haven_FL = urllib.parse.urlencode({
    'access_key': '2f18961718a89cea8627fcc20480d31a',
    'query': 'land-Winter Haven',
    'region': 'Florida ',
    'limit': 1,
    })
Las_Vegas_Genderson_paradise_NV = urllib.parse.urlencode({
    'access_key': '2f18961718a89cea8627fcc20480d31a',
    'query': 'Las Vegas-Henderson-Paradise',
    'region': 'Nevada.  ',
    'limit': 1,
    })
logan_UT = urllib.parse.urlencode({
    'access_key': '2f18961718a89cea8627fcc20480d31a',
    'query': 'Logan',
    'region': 'Utah  ',
    'limit': 1,
    })
Longview_WA = urllib.parse.urlencode({
    'access_key': '2f18961718a89cea8627fcc20480d31a',
    'query': 'Longview',
    'region': 'Washington  ',
    'limit': 1,
    })
Mount_-vernon_Anacortes = urllib.parse.urlencode({
    'access_key': '2f18961718a89cea8627fcc20480d31a',
    'query': 'Mount Vernon-Anacortes',
    'region': 'Washington  ',
    'limit': 1,
    })
Ocala_FL = urllib.parse.urlencode({
    'access_key': '2f18961718a89cea8627fcc20480d31a',
    'query': 'Ocala',
    'region': 'Florida ',
    'limit': 1,
    })
Ogden_Cleardield_UT = urllib.parse.urlencode({
    'access_key': '2f18961718a89cea8627fcc20480d31a',
    'query': 'Ogden-Clearfield',
    'region': 'Utah   ',
    'limit': 1,
    }) 
Olympia_lacey_tumwater_WA = urllib.parse.urlencode({
    'access_key': '2f18961718a89cea8627fcc20480d31a',
    'query': 'Olympia-lacey-tumwater',
    'region': 'Washington  ',
    'limit': 1,
    })
Palm_bay_melbourne_Titusville_WA = urllib.parse.urlencode({
    'access_key': '2f18961718a89cea8627fcc20480d31a',
    'query': 'Palm Bay-Melbourne-Titusville',
    'region': 'Florida ',
    'limit': 1,
    })
Phoenix_Mesa_chandler_AZ = urllib.parse.urlencode({
    'access_key': '2f18961718a89cea8627fcc20480d31a',
    'query': 'Phoenix-Mesa-Chandler',
    'region': 'Arizona',
    'limit': 1,
    })
Pocatello_ID = urllib.parse.urlencode({
    'access_key': '2f18961718a89cea8627fcc20480d31a',
    'query': 'Pocatello',
    'region': 'Indiana',
    'limit': 1,
    })
Port_ST_lucie_FL = urllib.parse.urlencode({
    'access_key': '2f18961718a89cea8627fcc20480d31a',
    'query': 'Port St. Lucie',
    'region': 'Florida',
    'limit': 1,
    })
Prescott_Valley_prescott_AZ = urllib.parse.urlencode({
    'access_key': '2f18961718a89cea8627fcc20480d31a',
    'query': 'Prescott Valley-Prescott',
    'region': 'Arizona',
    'limit': 1,
    })
Provo_Orem_UT = urllib.parse.urlencode({
    'access_key': '2f18961718a89cea8627fcc20480d31a',
    'query': 'Provo-Orem',
    'region': 'Utah',
    'limit': 1,
    })
Pueblo_CO = urllib.parse.urlencode({
    'access_key': '2f18961718a89cea8627fcc20480d31a',
    'query': 'Pueblo',
    'region': 'Colorado',
    'limit': 1,
    })
Punta_gorda_FL = urllib.parse.urlencode({
    'access_key': '2f18961718a89cea8627fcc20480d31a',
    'query': 'Punta Gorda',
    'region': 'Florida',
    'limit': 1,
    })
Reno_NV = urllib.parse.urlencode({
    'access_key': '2f18961718a89cea8627fcc20480d31a',
    'query': 'Reno',
    'region': 'Nevada',
    'limit': 1,
    })
Salem_OR = urllib.parse.urlencode({
    'access_key': '2f18961718a89cea8627fcc20480d31a',
    'query': 'Salem',
    'region': 'Oregon',
    'limit': 1,
    })
Salt_Lake_city_UT = urllib.parse.urlencode({
    'access_key': '2f18961718a89cea8627fcc20480d31a',
    'query': 'Salt Lake City',
    'region': 'Utah',
    'limit': 1,
    })
Sebastion_vero_beach_FL =urllib.parse.urlencode({
    'access_key': '2f18961718a89cea8627fcc20480d31a',
    'query': 'Sebastian-Vero Beach',
    'region': 'Florida',
    'limit': 1,
    })
sebring_Avalon_Park_FL = urllib.parse.urlencode({
    'access_key': '2f18961718a89cea8627fcc20480d31a',
    'query': 'Sebring-Avon Park',
    'region': 'Florida',
    'limit': 1,
    })
Spokane_Spokane_valley_WA = urllib.parse.urlencode({
    'access_key': '2f18961718a89cea8627fcc20480d31a',
    'query': 'Sevring-Avon Park',
    'region': 'Florida',
    'limit': 1,
    })
ST_George_UT = urllib.parse.urlencode({
    'access_key': '2f18961718a89cea8627fcc20480d31a',
    'query': 'ST. George',
    'region': 'Utah',
    'limit': 1,
    })

tampa-St_George_UT = urllib.parse.urlencode({
    'access_key': '2f18961718a89cea8627fcc20480d31a',
    'query': 'Tampa-St. Petersburg-Clearwater',
    'region': 'Florida',
    'limit': 1,
    })
Twin_falls_ID = urllib.parse.urlencode({
    'access_key': '2f18961718a89cea8627fcc20480d31a',
    'query': 'Twin Falls',
    'region': 'Idaho',
    'limit': 1,
    })








conn.request('GET', '/v1/forward?{}'.format(params))

res = conn.getresponse()
data = res.read()

print(data.decode('utf-8'))
# Out:
#   File "C:\Users\think\AppData\Local\Temp/ipykernel_10268/161968972.py", line 116
#     Mount_-vernon_Anacortes = urllib.parse.urlencode({
#                                                       ^
# SyntaxError: can't assign to operator
